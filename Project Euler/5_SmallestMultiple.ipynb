# %% [markdown]
# # Problem 5: Smallest Multiple.

# %% [markdown]
# ![image.png](attachment:0a43b479-11fc-4004-8cd8-b9d3562f007a.png)

# %%
# %%time
def smallest_multiple(bot, top):
    '''Return the smallest positive number that is evenly divisible by all of the numbers between bot & top'''
    n = top
    s = True
    while s:
        for i in range(bot, top +1):
            if n % i != 0:
                break
            if i == top:
                return n
                s = False
        n += top
smallest_multiple(1,20)
# Out:
# Wall time: 5.74 s
# 232792560
