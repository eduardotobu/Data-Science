# %% [markdown]
# # Image color extraction with Python

# %% [markdown]
# ## Image Reading

# %%
from PIL import Image
Image.open(r"/Users/eduardotorresburgos/Documents/GitHub/Data-Science/Building Blocks/Image Analysis/Images/8_Rosas_y_Mini_rosas_en_Jarron_pr.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=434x609 at 0x7FEF905EAED0>

# %% [markdown]
# ## Agrupation of colors using K-Means

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread("/Users/eduardotorresburgos/Documents/GitHub/Data-Science/Building Blocks/Image Analysis/Images/8_Rosas_y_Mini_rosas_en_Jarron_pr.jpeg")
w, h, d = tuple(image.shape)
pixels = np.reshape(image,(w * h, d))

from sklearn.cluster import KMeans
n_colors = 8 #Number of colors displayed in the visualization
model = KMeans(n_clusters = n_colors, random_state = 42).fit(pixels)
palette = np.uint8(model.cluster_centers_)

plt.imshow([palette])
plt.show()
